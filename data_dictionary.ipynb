# %% [markdown]
# # Data Dictionary
# This is the data dictionary to correspond with the follow csv files.
#
# ## Anxiety
# |Field   |Description|
# |:----:  | :----:    |
# |ID   | Unique Identifier  |
# |Age | Age   |
# |Gender | Gender  |
# |Occupation | Occupation of participant  |
# |Sleep Hours | Avg sleep hrs/night  |
# |Physical Activity| (hrs/week) |
# |Caffeine Intake |(mg/day) |
# |Alcohol Consumption |(drinks/week)  |
# |Smoking  | Does participant smoke? |
# |Family History of Anxiety| Is there a history of anxiety? |
# |Stress Level |(1-10)  |
# |Heart Rate |(bpm during attack) |
# |Breathing Rate | (breaths/min) |
# |Sweating Level |(1-5) |
# |Dizziness | Dizziness (yes/no)  |
# |Medication | Medication (yes/no)  |
# |Therapy Sessions |(per month)  |
# |Recent Major Life Event | (yes/no)   |
# |Diet Quality | (1-10)  |
# |Severity of Anxiety Attack |  (1-10)  |
#
# ## Obesity
# |Field   |Description|
# |:----:  | :----:    |
# | Gender | Gender    |
# |Age     | Ages of participants   |
# |Height  | Height in Kgs          |
# |Weight   | Weight in kgs    |
# |family_history |Has a family member suffered or suffers from overweight?  |
# |FAVC | Do you eat high caloric food frequently?  |
# |FCVC | Do you usually eat vegetables in your meals?  |
# |NCP | How many main meals do you have daily?  |
# |CAEC | Do you eat any food between meals?  |
# |SMOKE | Do you smoke?  |
# |CH2O | How much water do you drink daily?  |
# |SCC | Do you monitor the calories you eat daily?  |
# |FAF | How often do you have physical activity?  |
# |TUE | How much time do you use technological devices such as cell phone, videogames, television, computer and others?  |
# |CALC | How often do you drink alcohol?  |
# |MTRANS | Which transportation do you usually use?  |
# |Obesity_level | Obesity level |
#
# ## Panic Attacks
# |Field   |Description|
# |:----:  | :----:    |
# |ID| Unique Identifier  |
# |Age| Age  |
# |Gender| Gender  |
# |Panic_Attack_Frequency| Frequency of attacks  |
# |Duration_Minutes| Duration of attacks  |
# |Trigger| Any triggers?  |
# |Heart_Rate| Heart rate during attacks  |
# |Sweating| Sweating during attacks  |
# |Shortness_of_Breath| Shortness of breath during attacks  |
# |Dizziness| dizziness during attacks  |
# |Chest_Pain| Any chest pain?  |
# |Trembling| Any trembling?  |
# |Medical_History| Any medical history of participant?  |
# |Medication| Does participant take any medicine?  |
# |Caffeine_Intake| Caffeine intake per day  |
# |Exercise_Frequency| Frequency of exercise  |
# |Sleep_Hours| Avg number of hrs slept per night  |
# |Alcohol_Consumption| Avg alcohol consumption  |
# |Smoking| Does participant smoke?  |
# |Therapy| Does participant go to therapy?   |
# |Panic_Score| Overall panic score  |
